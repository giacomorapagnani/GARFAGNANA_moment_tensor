# %%
#download catalogue from INGV

# %% LIB
from obspy.clients.fdsn.client import Client
from obspy import UTCDateTime
from obspy.core.event import Catalog
from obspy.core.stream import Stream
from obspy.core.event import Event
from obspy.core.event import Origin
from obspy.core.event import Magnitude
from obspy import read_events
from obspy import read_inventory
from obspy.core.event import ResourceIdentifier
import cartopy.crs as ccrs

from pyrocko import util, model, io, trace, moment_tensor, gmtpy
from pyrocko import pz
from pyrocko import orthodrome as od
from pyrocko.io import quakeml
from pyrocko.io import stationxml as fdsn
from pyrocko.client import catalog
from pyrocko.automap import Map

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import csv

# %% [markdown]
# # rectangular search

# %%
# rectangular search
workdir= '../'
catdir =  os.path.join(workdir,'CAT')

client=Client('INGV')

stime=UTCDateTime('1980-01-01T00:00:00')        # CHANGE set start time
etime=UTCDateTime('2014-01-01T00:00:00')        # CHANGE set end time

minlat=40.75                                       # CHANGE
maxlat=40.90                                       # CHANGE
minlon=14.00                                       # CHANGE
maxlon=14.20                                     # CHANGE

minmag=1.

catalogue_filename= 'catalogue_flegrei_1980_2014'              # CHANGE

print('downloading events from INGV database')
cat_INGV=client.get_events(starttime=stime,endtime=etime,
                        minlatitude=minlat,maxlatitude=maxlat,minlongitude=minlon,
                        maxlongitude=maxlon,minmagnitude=minmag)


cat_name=os.path.join(catdir,catalogue_filename + '.xml')
cat_INGV.write(cat_name,format='QUAKEML')

print('number of events selected:',len(cat_INGV))
print(cat_INGV)

# %% [markdown]
# # circular search

# %%
# circular search
workdir= '../'
catdir =  os.path.join(workdir,'CAT')

client=Client('INGV')

stime=UTCDateTime('2010-01-01T00:00:00')        # CHANGE set start time
etime=UTCDateTime('2026-04-01T00:00:00')        # CHANGE set end time

lat=44.1507                                      # CHANGE
lon=10.0467                                      # CHANGE
minrad=0.0      # degrees
maxrad=0.2     # degrees

maxdepth=50.    # km

minmag=2.5

catalogue_filename= 'catalogue_garfagnana'              # CHANGE

print('downloading events from INGV database')
cat_INGV=client.get_events(starttime=stime,endtime=etime,
                        latitude=lat,longitude=lon,
                        minradius=minrad,maxradius=maxrad,
                        maxdepth=maxdepth,minmagnitude=minmag)


cat_name=os.path.join(catdir,catalogue_filename + '.xml')
cat_INGV.write(cat_name,format='QUAKEML')

print('number of events selected:',len(cat_INGV))
print(cat_INGV)
# Out:
# downloading events from INGV database
# ---------------------------------------------------------------------------
# FDSNBadGatewayException                   Traceback (most recent call last)
# Cell In[3], line 22
#      19 catalogue_filename= 'catalogue_garfagnana'              # CHANGE
#      21 print('downloading events from INGV database')
# ---> 22 cat_INGV=client.get_events(starttime=stime,endtime=etime,
#      23                         latitude=lat,longitude=lon,
#      24                         minradius=minrad,maxradius=maxrad,
#      25                         maxdepth=maxdepth,minmagnitude=minmag)
#      28 cat_name=os.path.join(catdir,catalogue_filename + '.xml')
#      29 cat_INGV.write(cat_name,format='QUAKEML')
#
# File /opt/homebrew/lib/python3.11/site-packages/obspy/clients/fdsn/client.py:550, in Client.get_events(self, starttime, endtime, minlatitude, maxlatitude, minlongitude, maxlongitude, latitude, longitude, minradius, maxradius, mindepth, maxdepth, minmagnitude, maxmagnitude, magnitudetype, eventtype, includeallorigins, includeallmagnitudes, includearrivals, eventid, limit, offset, orderby, catalog, contributor, updatedafter, filename, **kwargs)
#     545 setup_query_dict('event', locs, kwargs)
#     547 url = self._create_url_from_parameters(
#     548     "event", DEFAULT_PARAMETERS['event'], kwargs)
# --> 550 data_stream = self._download(url)
#     551 data_stream.seek(0, 0)
#     552 if filename:
#
# File /opt/homebrew/lib/python3.11/site-packages/obspy/clients/fdsn/client.py:1486, in Client._download(self, url, return_string, data, use_gzip, content_type)
#    1481     headers['Content-Type'] = content_type
#    1482 code, data = download_url(
#    1483     url, opener=self._url_opener, headers=headers,
#    1484     debug=self.debug, return_string=return_string, data=data,
#    1485     timeout=self.timeout, use_gzip=use_gzip)
# -> 1486 raise_on_error(code, data)
#    1487 return data
#
# File /opt/homebrew/lib/python3.11/site-packages/obspy/clients/fdsn/client.py:1846, in raise_on_error(code, data)
#    1843     raise FDSNNotImplementedException("Service responds: Not implemented ",
#    1844                                       server_info)
#    1845 elif code == 502:
# -> 1846     raise FDSNBadGatewayException("Service responds: Bad gateway ",
#    1847                                   server_info)
#    1848 elif code == 503:
#    1849     raise FDSNServiceUnavailableException("Service temporarily "
#    1850                                           "unavailable",
#    1851                                           server_info)
#
# FDSNBadGatewayException: Service responds: Bad gateway
# HTTP Status code: 502
# Detailed response of server:

# %% [markdown]
# # create pf catalogue

# %%
# create/load pf catalogue
catname_pf = os.path.join(catdir, catalogue_filename + '.pf')
label='garfagnana_'      ### CHANGE ###
def catalogue_INGV_to_PF(cat,cat_name,label=''):
    events = []
    for ev in cat:
        timetmp= str(ev.origins[0].time)
        timestr = timetmp[0:10] + ' ' + timetmp[11:23]                          # format: '2010-01-01 00:00:00.000'
        time = util.str_to_time(timestr)
        
        name= label + timestr[0:4] + '_' + timestr[5:7] + '_' + timestr[8:10] + '_' + timestr[11:13] + '_' + timestr[14:16] + '_' + timestr[17:19]

        lat=    float( ev.origins[0].latitude )
        lon =   float( ev.origins[0].longitude )
        depth = float( ev.origins[0].depth )
        magnitude = float( ev.magnitudes[0].mag )
        events.append(model.Event(name=name, time=time,
                                lat=lat, lon=lon,
                                depth=depth, magnitude=magnitude))
    events.sort(key=lambda x: x.time, reverse=False)
    model.dump_events(events, cat_name)
    return events

print('creating catalogues INGV in .pf')
cat_pf_INGV=    catalogue_INGV_to_PF(cat_INGV,catname_pf,label)

# %% [markdown]
# # EXTRA: create .txt file of the catalogue

# %%
# %% EXTRA: create .txt file of the catalogue
def create_txt_catalogue(catalogue):
    list_events=[]
    for ev in catalogue:
        list_events.append( util.time_to_str(ev.time)+'\t'+str(ev.lat)
                           +'\t'+str(ev.lon)+'\t' +str(ev.depth)+'\t'+str(ev.magnitude) )
    return list_events

# columns:  TIME    LAT     LON     DEPTH   MAGNITUDE
######################################################################################
######################################################################################
switch_create_txt_file_with_catalogue= True      ########################    SWITCH
######################################################################################
######################################################################################

if switch_create_txt_file_with_catalogue:
    print('Creating a txt file of the selected catalogue')
    cat=model.load_events(catname_pf)                                                         
    l_ev=create_txt_catalogue(cat)

    new_file = os.path.join(catdir,catalogue_filename + '.txt')

    with open(new_file, 'w') as output:
        output.write('time lat lon depth magnitude\n')
        for row in l_ev:
            output.write(str(row) + '\n')


# %% CHECK DATA NAME'S CONSISTENCIES:
# DATA
# BLACKLIST
# MARKERS
